# %%
import pandas as pd
import numpy as np

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
df = pd.read_csv(url, header = None)

# %%
headers = ["symboling", "normalized-losses", "make", "fuel-type", "aspiration", "num-of-doors", "body-style", "drive-wheels", "engine-location", "wheel-base", " length", "width", "height", "curb-weight", "engine-type", "num-of-cylinders", "engine-size", "fuel-system", "bore", "stroke", "compression-ratio", "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"]
df.columns = headers

# %%
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
#  length              float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.describe(include = 'all')
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           205        205          205             205  205.000000  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
#  length              205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null object
# stroke               205 non-null object
# ...

# %%
df.dropna(subset = ['price'], axis = 0, inplace = True )

# %%
mean = df["compression-ratio"].mean()
df["compression-ratio"].replace(np.nan, mean)
# Out:
# 0       9.0
# 1       9.0
# 2       9.0
# 3      10.0
# 4       8.0
#        ...
# 200     9.5
# 201     8.7
# 202     8.8
# 203    23.0
# 204     9.5
# Name: compression-ratio, Length: 205, dtype: float64

# %%
df["city-mpg"] = 235/df["city-mpg"]
df.rename(columns = {"city-mpg" : "city-L/100km"}, inplace = True)

# %%
df["price"].replace('?', 0, inplace = True)

# %%
df["price"] = df["price"].astype('float64')
df['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
bins = np.linspace(min(df['price']), max(df['price']), 4)
group = ['low', 'mid', 'high']
df['price-binned'] = pd.cut(df['price'], bins, labels = group, include_lowest = True)

# %%
df2 = df['price-binned'].value_counts()

# %%
df1 = pd.get_dummies(df['fuel-type'])

# %%
df = pd.concat([df, df1], axis = 1)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_test = df[['drive-wheels', 'body-style', 'price']]
df_grp = df_test.groupby(['drive-wheels', 'body-style'], as_index = False).mean()
df_grp
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   3801.500000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9467.526316
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  13583.157895
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
df_pivot = df_grp.pivot(index = 'drive-wheels', columns = 'body-style')
df_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   3801.500000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9467.526316
# rwd              23949.6  24202.714286  13583.157895  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
import scipy.stats as stats
df_anova = df[['make', 'price']]
grp_anova = df_anova.groupby(['make'])
anova_res = stats.f_oneway(grp_anova.get_group('honda')['price'], grp_anova.get_group('subaru')['price'])
anova_res
# Out:
# F_onewayResult(statistic=0.19744030127462606, pvalue=0.6609478240622193)

# %%
df['horsepower'] = df['horsepower'].replace('?', 0).astype('float64')
p_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
p_coef, p_value
# Out:
# (0.6912878787942788, 1.8175735366187956e-30)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
x = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
y = df[['price']]
lr.fit(x, y)
y_pred = lr.predict(x)
lr.score(x, y)
# Out:
# 0.7368395989355068

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.regplot( x = 'highway-mpg', y = 'price', data = df)

# %%
sns.residplot(df['highway-mpg'], df['price'])

# %%
ax1 = sns.distplot(df['price'], hist = False, color = 'r', label = 'Actual Value')
sns.distplot(y_pred, hist = False, color = 'b', label = 'Fitted Value', ax = ax1)

# %%
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline

# %%
Input = [('scale', StandardScaler()), ('poly', PolynomialFeatures(degree = 2)), ('model', LinearRegression())]
pipe = Pipeline(Input)
pipe.fit(x, y)
y_pred2 = pipe.predict(x)
pipe.score(x, y)
# Out:
# 0.8167957916383517

# %%
ax1 = sns.distplot(df['price'], hist = False, color = 'r', label = 'Actual Value')
sns.distplot(y_pred2, hist = False, color = 'b', label = 'Fitted Value', ax = ax1)

# %%
scale2 = StandardScaler()
scale2.fit(x)
x_scale = scale2.transform(x)
pr = PolynomialFeatures(degree = 2)
pr.fit(x_scale)
x_pr = pr.transform(x_scale)
lm = LinearRegression()
lm.fit(x_pr, y)
y_pred3 = lm.predict(x_pr)
lm.score(x_pr, y)
# Out:
# 0.8167957916383517

# %%
ax1 = sns.distplot(df['price'], hist = False, color = 'r', label = 'Actual Value')
sns.distplot(y_pred3, hist = False, color = 'b', label = 'Fitted Value', ax = ax1)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y, y_pred)
# Out:
# 17092937.937706746

# %%
from sklearn.model_selection import train_test_split
xt, xte, yt, yte = train_test_split(x, y, test_size = 0.3, random_state = 0)
pipe.fit(xt, yt)
yp = pipe.predict(xte)
pipe.score(xt, yt)
# Out:
# 0.8237489642290977

# %%
ax1 = sns.distplot(yte, hist = False, color = 'r', label = 'Actual Value')
sns.distplot(yp, hist = False, color = 'b', label = 'Fitted Value', ax = ax1)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(pipe, x, y, cv = 3)
np.mean(scores)
# Out:
# 0.6221999863811473

# %%
from sklearn.model_selection import cross_val_predict
ym = cross_val_predict(pipe, x, y, cv = 3)
ym
# Out:
# array([[ 1.20498722e+04],
#        [ 1.20498722e+04],
#        [ 1.69873622e+04],
#        [ 1.02789567e+04],
#        [ 1.36610461e+04],
#        [ 1.14284624e+04],
#        [ 1.34758646e+04],
#        [ 1.41660797e+04],
#        [ 1.77338847e+04],
#        [ 1.79308059e+04],
#        [ 1.02669584e+04],
#        [ 1.02669584e+04],
#        [ 1.48431498e+04],
#        [ 1.50326940e+04],
#        [ 1.68935798e+04],
#        [ 2.48977935e+04],
#        [ 2.38812896e+04],
#        [ 2.52600356e+04],
#        [ 4.35433053e+03],
#        [ 6.56459323e+03],
#        [ 6.46556582e+03],
#        [ 6.82701886e+03],
#        [ 6.53615200e+03],
#        [ 1.05778583e+04],
#        [ 6.76298076e+03],
#        [ 6.81892693e+03],
#        [ 6.81892693e+03],
#        [ 1.04779002e+04],
#        [ 1.00770263e+04],
#        [ 1.77670360e+04],
#        [ 3.80537545e+03],
#        [ 7.29783858e+03],
#        [ 6.34580360e+03],
#        [ 6.57866348e+03],
#        [ 6.63384638e+03],
# ...

# %%
ax1 = sns.distplot(y, hist = False, color = 'r', label = 'Actual Value')
sns.distplot(ym, hist = False, color = 'b', label = 'Fitted Value', ax = ax1)

# %%
rsqu = []
order = [1,2,3,4]
for n in order:
    p = PolynomialFeatures(degree = n)
    p.fit(xt)
    xt_p = p.transform(xt)
    p.fit(xte)
    xte_p = p.transform(xte)
    lm.fit(xt_p, yt)
    rsqu.append(lm.score(xte_p, yte))
    
rsqu
# Out:
# [0.5543912632831028,
#  -0.36318569957258995,
#  -9.57538859462278,
#  -1207.7025149103715]

# %%
from sklearn.linear_model import Ridge
e = []
l = [10, 1, 0, 0.1, 0.05]
for m in l:
    rigemodel = Ridge(alpha = m)
    rigemodel.fit(x, y)
    y_v = rigemodel.predict(x)
    e.append(rigemodel.score(x,y))
e
# Out:
# [0.7368395117031585,
#  0.7368395980575974,
#  0.7368395989355068,
#  0.736839598926722,
#  0.7368395989333105]

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
param = [{ 'alpha' :[0.01, 0.1, 0, 1, 10, 100, 1000], 'normalize' : [ True, False]}]
rr = Ridge()
grid = GridSearchCV(rr, param, cv = 4)
grid.fit(x, y)
grid.best_estimator_
score = grid.cv_results_
score['mean_test_score']
# Out:
# array([ 0.63131951,  0.62546102,  0.64854147,  0.62546237,  0.62546087,
#         0.62546087,  0.62407483,  0.62547584,  0.29003768,  0.62560951,
#         0.02105633,  0.62684632, -0.02051202,  0.63342604])
